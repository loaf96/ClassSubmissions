# %%
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
city_data_to_load = "data/city_data.csv"
ride_data_to_load = "data/ride_data.csv"

# %%
# Read the City and Ride Data
with open(city_data_to_load):
    city_data = pd.read_csv(city_data_to_load)
with open(ride_data_to_load):
    ride_data = pd.read_csv(ride_data_to_load)
# Combine the data into a single dataset
all_data = pd.merge(city_data, ride_data, on='city')
# Display the data table for preview
nec_data = (all_data.set_index('type'))
nec_data.head()
# Out:
#               city  driver_count                 date   fare        ride_id
# type
# Urban  Richardfort            38  2018-02-24 08:40:38  13.93  5628545007794
# Urban  Richardfort            38  2018-02-13 12:46:07  14.00   910050116494
# Urban  Richardfort            38  2018-02-16 13:52:19  17.92   820639054416
# Urban  Richardfort            38  2018-02-01 20:18:28  10.26  9554935945413
# Urban  Richardfort            38  2018-04-17 02:26:37  23.00   720020655850

# %% [markdown]
# ## Bubble Plot of Ride Sharing Data

# %%
# Obtain the x and y coordinates for each of the three city types
# individual datasets created for each type for easier munging
urb_data = pd.DataFrame(nec_data.loc['Urban', ['city', 'driver_count', 'fare']]).reindex()
sub_data = pd.DataFrame(nec_data.loc['Suburban', ['city', 'driver_count', 'fare']]).reindex()
rur_data = pd.DataFrame(nec_data.loc['Rural', ['city', 'driver_count', 'fare']]).reindex()

# function used to mung (idk if I am using that word correctly) data sets previously created
def cln_cln(df):
    frsh = pd.unique(df['city'])
    so_frsh = []
    cln = df.set_index('city')
    for y in frsh:
        avg_f = cln.loc[y, 'fare']
        avg_f = round(avg_f.mean(), 2)
        num_dr = cln.loc[y, 'driver_count']
        num_rids = num_dr.value_counts()
        so_frsh.append({'city': y, 'Average Fare': avg_f, '# of Drivers': num_dr.values[0], '# of Rides': num_rids.values[0]})
        next
    return so_frsh

# use of function cln_cln
frshcln_urb = pd.DataFrame(cln_cln(urb_data))
frshcln_sub = pd.DataFrame(cln_cln(sub_data))
frshcln_rur = pd.DataFrame(cln_cln(rur_data))
# Build the scatter plots for each city types
fc_count = 0

def scat_dat(df, fc):
    if fc == 0:
        fc = 'gold'
    elif fc == 1:
        fc = 'coral'
    else:
        fc = 'skyblue' 
    scat_it = plt.scatter(df['# of Rides'], df['Average Fare'], 
                          s=df['# of Drivers'], facecolors= fc)
    return scat_it


print(frshcln_urb)
scat_dat(frshcln_urb, 0)
scat_dat(frshcln_sub, 1)
scat_dat(frshcln_rur, 2)
# Incorporate the other graph properties

# Create a legend

# Incorporate a text label regarding circle size

# Save Figure
# Out:
#     # of Drivers  # of Rides  Average Fare                  city
# 0             38          28         22.37           Richardfort
# 1             59          23         24.36          Williamsstad
# 2             67          19         23.84           Port Angela
# 3             34          23         28.62            Rodneyfort
# 4             39          31         25.12           West Robert
# 5             70          30         24.74          West Anthony
# 6             48          39         25.99           West Angela
# 7             25          24         22.65         Martinezhaven
# 8             22          17         26.34             Karenberg
# 9             26          22         25.33           Barajasview
# 10            12          20         23.06            Robertport
# 11            39          25         22.29          Joneschester
# 12            17          21         21.24               Leahton
# 13            32          26         24.42  West Christopherberg
# 14            27          21         26.79               Johnton
# 15            67          19         21.92          Reynoldsfurt
# 16             7          22         25.85            Port David
# 17            33          30         22.59   New Kimberlyborough
# 18            52          27         28.31           Carriemouth
# 19            25          22         22.10             Rogerston
# 20            64          25         25.65              Jerryton
# 21            23          28         25.29             Loganberg
# 22            21          24         23.36          Simpsonburgh
# 23            23          33         27.20            Port Frank
# 24            10          19         20.09          South Latoya
# 25            73          25         21.77      West Samuelburgh
# 26            61          25         25.22           Grahamburgh
# 27            25          16         28.23   West Patrickchester
# 28            19          25         22.62        North Madeline
# 29            46          19         22.97            South Jack
# ..           ...         ...           ...                   ...
# 36            11          31         26.73         South Evanton
# 37            19          26         24.84       Lake Danielberg
# 38            65          29         23.76       East Kaylahaven
# 39            28          28         23.13            West Heidi
# 40             5          28         27.45             Karenside
# 41             4          38         26.54       South Karenland
# 42            57          23         20.35          West Gabriel
# 43            22          14         27.50        North Markport
# 44            11          25         21.48          Raymondhaven
# 45            18          22         23.49         North Barbara
# 46            58          24         23.81         Lake Scottton
# 47            45          26         21.72       West Josephberg
# 48            59          21         23.98             Pattyland
# 49            72          31         24.45    South Michelleport
# 50            41          27         24.50       Christopherfurt
# 51            45          22         24.64          Valentineton
# 52            38          31         28.57         South Phillip
# 53             6          35         22.74           North Jason
# 54            49          19         25.84             Deanville
# 55             5          24         23.43    Lake Jonathanshire
# 56            44          19         27.82           New Paulton
# 57            36          28         25.89           Hurleymouth
# 58             3          22         23.01         Port Johnbury
# 59            33          30         25.21         North Jasmine
# 60            44          22         21.68         New Paulville
# 61            12          18         24.64           Amandaburgh
# 62            46          20         26.60          Williamsview
# 63            50          18         26.77        New Jacobville
# 64            57          25         25.64    Port Samanthamouth
# 65            47          24         23.73           Roberthaven
#
# [66 rows x 4 columns]
